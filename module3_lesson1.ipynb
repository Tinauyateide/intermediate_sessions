# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/tina/intermidiate_sessions/all_alpha_08 (1).csv")
df
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#        'Underhood ID', 'Veh Class', 'Air Pollution Score', 'FE Calc Appr',
#        'City MPG', 'Hwy MPG', 'Cmb MPG', 'Unadj Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales_Area', 'Stnd',
#        'Underhood_ID', 'Veh_Class', 'Air_Pollution_Score', 'FE_Calc_Appr',
#        'City_MPG', 'Hwy_MPG', 'Cmb_MPG', 'Unadj_Cmb_MPG',
#        'Greenhouse_Gas_Score', 'SmartWay'],
#       dtype='object')

# %%
df.head(10)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales_Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 5   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline         CA   U2
# 7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline         CA   U2
# 8   ACURA TL    3.5  (6 cyl)    Man-6   2WD  Gasoline         CA   U2
# 9   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline         FA   B5
#
#    Underhood_ID    Veh_Class Air_Pollution_Score FE_Calc_Appr City_MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# ...

# %%
df.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales_Area               object
# Stnd                     object
# Underhood_ID             object
# Veh_Class                object
# Air_Pollution_Score      object
# FE_Calc_Appr             object
# City_MPG                 object
# Hwy_MPG                  object
# Cmb_MPG                  object
# Unadj_Cmb_MPG           float64
# Greenhouse_Gas_Score     object
# SmartWay                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Model                     0
# Displ                     0
# Cyl                     199
# Trans                   199
# Drive                    93
# Fuel                      0
# Sales_Area                0
# Stnd                      0
# Underhood_ID              0
# Veh_Class                 0
# Air_Pollution_Score       0
# FE_Calc_Appr            199
# City_MPG                199
# Hwy_MPG                 199
# Cmb_MPG                 199
# Unadj_Cmb_MPG           199
# Greenhouse_Gas_Score    199
# SmartWay                  0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Model                   0
# Displ                   0
# Cyl                     0
# Trans                   0
# Drive                   0
# Fuel                    0
# Sales_Area              0
# Stnd                    0
# Underhood_ID            0
# Veh_Class               0
# Air_Pollution_Score     0
# FE_Calc_Appr            0
# City_MPG                0
# Hwy_MPG                 0
# Cmb_MPG                 0
# Unadj_Cmb_MPG           0
# Greenhouse_Gas_Score    0
# SmartWay                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Displ  Unadj_Cmb_MPG
# count  2199.000000    2199.000000
# mean      3.593997      23.943561
# std       1.269747       6.353077
# min       1.300000      10.018400
# 25%       2.500000      19.143100
# 50%       3.500000      23.935100
# 75%       4.550000      27.888350
# max       8.400000      65.777800

# %%
d = df[df["Hwy_MPG"].str.contains("/")]
cols_name = ["Air_Pollution_Score","City_MPG","Hwy_MPG","Cmb_MPG","Greenhouse_Gas_Score"]
for x in cols_name:
    df[x] = df[x].apply(lambda x : x.split("/")[0])

# %%
df.head(10)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales_Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 5   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline         CA   U2
# 7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline         CA   U2
# 8   ACURA TL    3.5  (6 cyl)    Man-6   2WD  Gasoline         CA   U2
# 9   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline         FA   B5
#
#    Underhood_ID    Veh_Class Air_Pollution_Score FE_Calc_Appr City_MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# ...

# %%
df[["Air_Pollution_Score","City_MPG","Cmb_MPG","Greenhouse_Gas_Score"]] = df[["Air_Pollution_Score","City_MPG","Cmb_MPG","Greenhouse_Gas_Score"]].astype(float)

# %%
print("OUR DATAFRAME IS READY FOR VISUALIZATION")
df.dtypes
# Out:
# OUR DATAFRAME IS READY FOR VISUALIZATION
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales_Area               object
# Stnd                     object
# Underhood_ID             object
# Veh_Class                object
# Air_Pollution_Score     float64
# FE_Calc_Appr             object
# City_MPG                float64
# Hwy_MPG                  object
# Cmb_MPG                 float64
# Unadj_Cmb_MPG           float64
# Greenhouse_Gas_Score    float64
# SmartWay                 object
# dtype: object

# %%
corr_8 = df.corr()
corr_8
# Out:
#                          Displ  Air_Pollution_Score  City_MPG   Cmb_MPG  \
# Displ                 1.000000            -0.211347 -0.796726 -0.818928
# Air_Pollution_Score  -0.211347             1.000000  0.335070  0.328022
# City_MPG             -0.796726             0.335070  1.000000  0.982378
# Cmb_MPG              -0.818928             0.328022  0.982378  1.000000
# Unadj_Cmb_MPG        -0.777085             0.304071  0.925912  0.926908
# Greenhouse_Gas_Score -0.819581             0.263650  0.867844  0.893520
#
#                       Unadj_Cmb_MPG  Greenhouse_Gas_Score
# Displ                     -0.777085             -0.819581
# Air_Pollution_Score        0.304071              0.263650
# City_MPG                   0.925912              0.867844
# Cmb_MPG                    0.926908              0.893520
# Unadj_Cmb_MPG              1.000000              0.810233
# Greenhouse_Gas_Score       0.810233              1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(corr_8, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig= plt.figure(figsize=(16,10))
df.plot('Greenhouse_Gas_Score', 'Cmb_MPG' , kind = 'scatter', grid = True),
# Out:
# (<AxesSubplot:xlabel='Greenhouse_Gas_Score', ylabel='Cmb_MPG'>,)

# %%
sns.kdeplot(df["Air_Pollution_Score"], shade=True)
sns.kdeplot(df["Displ"], shade=True)
plt.legend(['Air_Pollution_Score',"Engine displacement"])
plt.xlabel(None)
plt.show()
