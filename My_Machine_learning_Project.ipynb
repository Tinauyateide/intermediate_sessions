# %% [markdown]
# # Project Overview
#
# In this project, i will build a machine learning model that will identify customers that are eligible for loan or not.

# %%
# IMPORTING MY LIBARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'C:\\Users\\Lydia': ['.bash_history', '.conda', '.condarc', '.continuum', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.vscode', '3D Objects', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'election_23.csv', 'election_3.csv', 'Favorites', 'IntelGraphicsProfiles', 'Links', 'loan_data_set.csv', 'Local Settings', 'Microsoft', 'module2 for lesson1.ipynb', 'Music', 'My Documents', 'My_Machine_learning_Project.ipynb', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'project.ipynb', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'teewts.ipynb', 'Templates', 'Untitled.ip
# ...

# %%
# read my dataset
train =pd.read_csv('loan_data_set.csv')

# %%
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %% [markdown]
# # Note
#
# our Dependant column has some unique values which we will be filtering later on

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Treating our missing values
#
# For this i will be creating a copy of my dataset just incase i need my original dataset later on and i will be writing a function that would treat the my missing values for the copy of my dataset.

# %%
df = train.copy()

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
def fill_na_values(df: pd.DataFrame) -> pd.DataFrame:
    for features in df:
        if df[features].isna().sum() > 0:
            if df[features].dtype == 'object':
                df[features].fillna(value=df[features].mode()[0], inplace=True)
            else:
                df[features].fillna(value=df[features].median(), inplace=True)
    return df

# %%
df=fill_na_values(df)

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Note
#
# while getting to konw our datatset earlier i found that in the Dependant Column has some unique vaules, i will filter those values and ill be converting them into (int)

# %%
df['Dependents'].replace('3+', 3,inplace=True)

# %%
df['Dependents'].dtype
# Out:
# dtype('O')

# %%
df['Dependents'] = df['Dependents'].astype(dtype = 'int64')

# %%
df['Dependents'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Visualizing the features of my Dataset

# %%
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           0      Graduate            No
# 1    LP001003    Male     Yes           1      Graduate            No
# 2    LP001005    Male     Yes           0      Graduate           Yes
# 3    LP001006    Male     Yes           0  Not Graduate            No
# 4    LP001008    Male      No           0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 609  LP002978  Female      No           0      Graduate            No
# 610  LP002979    Male     Yes           3      Graduate            No
# 611  LP002983    Male     Yes           1      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# We will be dropping our LoanID column seen as we would not be working with the column for our visuals

# %%
df.drop(
    labels=['Loan_ID'],
    inplace=True,
    axis=1
)

# %%
for feature in df:

    if df[feature].dtype == 'object':
        sns.countplot(
            data=df,
            x=feature
        )
        plt.title(f'Count plot of {feature}')
        plt.show()
    else:
        sns.displot(
            data=df,
            x=feature,
            kde=True
        )
        plt.title(f'Distribution plot of {feature}')
        plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for feature in df:

    le = LabelEncoder()

    if df[feature].dtype == 'object':

        df[feature] = le.fit_transform(df[feature])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

import numpy as np

# %%
X = df.drop(
    labels=['Loan_Status'],
    axis=1
).values

y = df['Loan_Status'].values

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=2022
)

# %%
def run_model(model) -> None:

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    score = f1_score(y_test, y_pred)

    print(f'F1 Score - {score}')

# %%
lr = LogisticRegression(max_iter=500)
run_model(lr)
# Out:
# F1 Score - 0.8775510204081634

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
run_model(rfc)
# Out:
# F1 Score - 0.8540540540540541

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...
